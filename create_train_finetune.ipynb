# %% [markdown]
# Base_finetune_data

# %%
import pandas as pd
import numpy as np
import utils

train_basecase = pd.read_csv("train_preds(train_only)/train_base_preds/train1_predictions.tsv",sep="\t")
originl_data  = pd.read_csv("NLP_dataset/MNLI_formatted/Shared_BaseTrain_MNLI.tsv",sep="\t")

# where data is the eval data and the second originl_train_data is the Shared_BaseTrain_MNLI.tsv data
output = utils.create_fintune_data(data = train_basecase,originl_train_data=originl_data,percent = 0.01)
output.to_csv("iteration1_finetune_train.tsv",sep="\t",index=False)
# Out:
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_percent_df["target"] =  int(len(df_sorted_delta)*percent) * [score_cols[0]]
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
# ...

# %%
train_basecase
# Out:
#         textid  target                        model  \
# 0            0       0  microsoft/deberta-base-mnli
# 1            1       0  microsoft/deberta-base-mnli
# 2            2       0  microsoft/deberta-base-mnli
# 3            3       0  microsoft/deberta-base-mnli
# 4            0       1  microsoft/deberta-base-mnli
# ...        ...     ...                          ...
# 479995       3  119998  microsoft/deberta-base-mnli
# 479996       0  119999  microsoft/deberta-base-mnli
# 479997       1  119999  microsoft/deberta-base-mnli
# 479998       2  119999  microsoft/deberta-base-mnli
# 479999       3  119999  microsoft/deberta-base-mnli
#
#                           tokenizer      predicted      prob  CONTRADICTION  \
# 0       microsoft/deberta-base-mnli  CONTRADICTION  0.684649       0.684649
# 1       microsoft/deberta-base-mnli  CONTRADICTION  0.907651       0.907651
# 2       microsoft/deberta-base-mnli        NEUTRAL  0.733460       0.171711
# ...

# %%
display(output)

output.to_csv("iteration1_finetune_train.tsv",sep="\t",index=False)
# Out:
#       textid                      pair  \
# 0          0    This example is Sports
# 1          1    This example is Sports
# 2          2    This example is Sports
# 3          3    This example is Sports
# 4          4    This example is Sports
# ...      ...                       ...
# 2395    2395    This example is Sports
# 2396    2396  This example is Sci/Tech
# 2397    2397     This example is World
# 2398    2398  This example is Business
# 2399    2399  This example is Business
#
#                                                    text          label
# 0     Madrid, Spain (Sports Network) - Real Madrid #...     ENTAILMENT
# 1      DALLAS (Sports Network) - Dirk Nowitzki score...     ENTAILMENT
# 2     Phoenix, AZ (Sports Network) - Quentin Richard...     ENTAILMENT
# 3      ORLANDO, Fl. (Sports Network) - Hedo Turkoglu...     ENTAILMENT
# 4      ORLANDO, Fl. (Sports Network) - Hedo Turkoglu...     ENTAILMENT
# ...

# %%
# this is just sanity check for the functions

# %%
col = "ENTAILMENT"

# Row with max entailment
max_row = train_basecase.groupby("target")["ENTAILMENT"].max()
second_max_row = train_basecase.groupby("target")["ENTAILMENT"].apply(lambda x: np.partition(x,-2)[-2])

np.max(max_row - second_max_row)
# Row with second max entailment


# print("Max row:\n", max_row)
# print("\nSecond max row:\n", second_max_row)
# Out:
# 0.9397252909839154

# %%
utils.get_positive_example(train_basecase,percent=0.01)
# Out:
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_percent_df["target"] =  int(len(df_sorted_delta)*percent) * [score_cols[0]]
#         textid      target                        model  \
# 103463       1  entailment  microsoft/deberta-base-mnli
# 85323        1  entailment  microsoft/deberta-base-mnli
# 115388       1  entailment  microsoft/deberta-base-mnli
# ...

# %% [markdown]
# # Chreate the finetune data used to train iteration 2

# %%
train_basecase = pd.read_csv("/Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/Model_Outputs/Model_seed_2_Yizhou/iteration_1/model2_iteration_1.tsv",sep="\t")
originl_data  = pd.read_csv("NLP_dataset/MNLI_formatted/Shared_BaseTrain_MNLI.tsv",sep="\t")
train_basecase
# Out:
#         textid  target                                              model  \
# 0            0       0  ../NLP_426/MNLI_Model2/finetune2/iteration_1/m...
# 1            1       0  ../NLP_426/MNLI_Model2/finetune2/iteration_1/m...
# 2            2       0  ../NLP_426/MNLI_Model2/finetune2/iteration_1/m...
# 3            3       0  ../NLP_426/MNLI_Model2/finetune2/iteration_1/m...
# 4            0       1  ../NLP_426/MNLI_Model2/finetune2/iteration_1/m...
# ...        ...     ...                                                ...
# 479995       3  119998  ../NLP_426/MNLI_Model2/finetune2/iteration_1/m...
# 479996       0  119999  ../NLP_426/MNLI_Model2/finetune2/iteration_1/m...
# 479997       1  119999  ../NLP_426/MNLI_Model2/finetune2/iteration_1/m...
# 479998       2  119999  ../NLP_426/MNLI_Model2/finetune2/iteration_1/m...
# 479999       3  119999  ../NLP_426/MNLI_Model2/finetune2/iteration_1/m...
#
#                                                 tokenizer      predicted  \
# ...

# %%
utils.get_positive_example(train_basecase,percent=0.01)["textid"].unique()
# Out:
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_percent_df["target"] =  int(len(df_sorted_delta)*percent) * [score_cols[0]]
# array([1])

# %%
output = utils.create_fintune_data(data = train_basecase,originl_train_data=originl_data,percent = 0.01)
# Out:
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_percent_df["target"] =  int(len(df_sorted_delta)*percent) * [score_cols[0]]
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
# ...

# %%
output.to_csv("iteration2_finetune_train.tsv",sep="\t",index=False)

# %% [markdown]
# # We got the evaluation that otput from iteration 2 now we take it and get a finetune for the final models

# %%
import pandas as pd
import numpy as np
import utils


train_basecase = pd.read_csv("Model_Outputs/Model_seed_2_Yizhou/iteration_2/model2_iteration_2.tsv",sep="\t")
originl_data  = pd.read_csv("NLP_dataset/MNLI_formatted/Shared_BaseTrain_MNLI.tsv",sep="\t")

# where data is the eval data and the second originl_train_data is the Shared_BaseTrain_MNLI.tsv data
output = utils.create_fintune_data(data = train_basecase,originl_train_data=originl_data,percent = 0.01)
output.to_csv("Model_Outputs/Model_seed_2_Yizhou/final_finetune/final_finetune_train.tsv",sep="\t",index=False)
# Out:
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_percent_df["target"] =  int(len(df_sorted_delta)*percent) * [score_cols[0]]
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
# ...
