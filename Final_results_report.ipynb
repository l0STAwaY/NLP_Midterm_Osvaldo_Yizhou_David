# %% [markdown]
# ## Base_Case_Evaluation

# %%
import utils
import pandas as pd
import numpy as np


text_classfication_true = pd.read_csv("NLP_dataset/Base_test_textClassification_AgNews.tsv",sep="\t")
MNLI_Basecase =  pd.read_csv("base_preds(tests_only)/initial_base_preds/test2_predictions.tsv",sep="\t")


Max_entailment = utils.top_entailment_per_target(MNLI_Basecase,"ENTAILMENT")

mapping_mask =  {0:"World" ,1:"Sports",2:"Business",3:"Sci/Tech"}

text_classfication_true["predicted"] =  Max_entailment["textid"].map(mapping_mask)
# Out:
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)

# %%
text_classfication_true["class"].value_counts()
# Out:
# class
# Business    1900
# Sci/Tech    1900
# Sports      1900
# World       1900
# Name: count, dtype: int64

# %%
Max_entailment_Top = utils.top_entailment_per_target(MNLI_Basecase,"ENTAILMENT")


# Sanity Check should not equal
np.min(Max_entailment["ENTAILMENT"])
np.min(MNLI_Basecase["ENTAILMENT"])


# Sanity Check should equal
np.max(Max_entailment["ENTAILMENT"])
np.max(MNLI_Basecase["ENTAILMENT"])
# Out:
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)
# 0.968251883983612

# %%
# Calculate Base case accuracy
# CONTRADICTION	NEUTRAL	ENTAILMENT
print(sum(Max_entailment["predicted"]=="ENTAILMENT"))
accruacy = sum(text_classfication_true["class"]==text_classfication_true["predicted"])/len(text_classfication_true["class"])
accruacy
# Out:
# 177
# 0.3285526315789474

# %%
Max_entailment["textid"].value_counts()
# Out:
# textid
# 2    2417
# 1    2218
# 3    1874
# 0    1091
# Name: count, dtype: int64

# %%
import utils
import pandas as pd
import numpy as np


text_classfication_true = pd.read_csv("NLP_dataset/Base_test_textClassification_AgNews.tsv",sep="\t")
MNLI_Basecase =  pd.read_csv("Model_Outputs/Model_seed_2_Yizhou/final_finetune/model2_final_eval.tsv",sep="\t")



Max_entailment = utils.top_entailment_per_target(MNLI_Basecase,"ENTAILMENT")

mapping_mask =  {0:"World" ,1:"Sports",2:"Business",3:"Sci/Tech"}

text_classfication_true["predicted"] =  Max_entailment["textid"].map(mapping_mask)
print(sum(Max_entailment["predicted"]=="ENTAILMENT"))

accruacy = sum(text_classfication_true["class"]==text_classfication_true["predicted"])/len(text_classfication_true["class"])
accruacy
# Out:
# 3325
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)
# 0.2501315789473684

# %%
Max_entailment
# Out:
#       textid  target                                              model  \
# 0          1       0  ../NLP_426/MNLI_Model2/finetune2/final_output/...
# 1          1       1  ../NLP_426/MNLI_Model2/finetune2/final_output/...
# 2          1       2  ../NLP_426/MNLI_Model2/finetune2/final_output/...
# 3          1       3  ../NLP_426/MNLI_Model2/finetune2/final_output/...
# 4          1       4  ../NLP_426/MNLI_Model2/finetune2/final_output/...
# ...      ...     ...                                                ...
# 7595       1    7595  ../NLP_426/MNLI_Model2/finetune2/final_output/...
# 7596       1    7596  ../NLP_426/MNLI_Model2/finetune2/final_output/...
# 7597       1    7597  ../NLP_426/MNLI_Model2/finetune2/final_output/...
# 7598       1    7598  ../NLP_426/MNLI_Model2/finetune2/final_output/...
# 7599       1    7599  ../NLP_426/MNLI_Model2/finetune2/final_output/...
#
#                                               tokenizer      predicted  \
# ...

# %%
text_classfication_true
# Out:
#                                                    text     class predicted
# 0     Unions representing workers at Turner   Newall...  Business    Sports
# 1     SPACE.com - TORONTO, Canada -- A second\team o...  Sci/Tech    Sports
# 2     AP - A company founded by a chemistry research...  Sci/Tech    Sports
# 3     AP - It's barely dawn when Mike Fitzpatrick st...  Sci/Tech    Sports
# 4     AP - Southern California's smog-fighting agenc...  Sci/Tech    Sports
# ...                                                 ...       ...       ...
# 7595  Ukrainian presidential candidate Viktor Yushch...     World    Sports
# 7596  With the supply of attractive pitching options...    Sports    Sports
# 7597  Like Roger Clemens did almost exactly eight ye...    Sports    Sports
# 7598  SINGAPORE : Doctors in the United States have ...  Business    Sports
# 7599  EBay plans to buy the apartment and home renta...  Business    Sports
#
# [7600 rows x 3 columns]

# %%
Max_entailment["textid"].map(mapping_mask).value_counts()
# Out:
# textid
# Sports      7598
# World          1
# Sci/Tech       1
# Name: count, dtype: int64

# %% [markdown]
# # Model 2 evaluation

# %%
text_classfication_true = pd.read_csv("NLP_dataset/Base_test_textClassification_AgNews.tsv",sep="\t")
MNLI_Basecase =  pd.read_csv("Model_Outputs/Model_seed_2_Yizhou//final_finetune/model2_final_eval.tsv",sep="\t")
Max_entailment = utils.top_entailment_per_target(MNLI_Basecase,"ENTAILMENT")

mapping_mask =  {0:"World" ,1:"Sports",2:"Business",3:"Sci/Tech"}

text_classfication_true["predicted"] =  Max_entailment["textid"].map(mapping_mask)
print(sum(Max_entailment["predicted"]=="ENTAILMENT"))

accruacy = sum(text_classfication_true["class"]==text_classfication_true["predicted"])/len(text_classfication_true["class"])
accruacy
# Out:
# 3325
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)
# 0.2501315789473684

# %%
Max_entailment["textid"].value_counts()
# Out:
# textid
# 1    7598
# 0       1
# 3       1
# Name: count, dtype: int64

# %% [markdown]
# # Train ACCURACY EVALUATION

# %%
# Check within train accuracy



text_classfication_true = pd.read_csv("NLP_dataset/MNLI_formatted/Shared_BaseTrain_MNLI.tsv",sep="\t")
MNLI_Basecase =  pd.read_csv("Model_Outputs/Model_seed_2_Yizhou//iteration_2/model2_iteration_2.tsv",sep="\t")



Max_entailment = utils.top_entailment_per_target(MNLI_Basecase,"ENTAILMENT")

mapping_mask =  {0:"World" ,1:"Sports",2:"Business",3:"Sci/Tech"}

text_classfication_true["predicted"] =  Max_entailment["textid"].map(mapping_mask)
print(sum(Max_entailment["predicted"]=="ENTAILMENT"))

accruacy = sum(text_classfication_true["class"]==text_classfication_true["predicted"])/len(text_classfication_true["class"])
accruacy
# Out:
# 22255
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)
# 0.0624

# %%
text_classfication_true = pd.read_csv("NLP_dataset/MNLI_formatted/Shared_BaseTrain_MNLI.tsv",sep="\t")
MNLI_Basecase =  pd.read_csv("Model_Outputs/Model_seed_2_Yizhou//iteration_2/model2_iteration_2.tsv",sep="\t")



Max_entailment = utils.top_entailment_per_target(MNLI_Basecase,"ENTAILMENT")

mapping_mask =  {0:"World" ,1:"Sports",2:"Business",3:"Sci/Tech"}

text_classfication_true["predicted"] =  Max_entailment["textid"].map(mapping_mask)
print(sum(Max_entailment["predicted"]=="ENTAILMENT"))

accruacy = sum(text_classfication_true["class"]==text_classfication_true["predicted"])/len(text_classfication_true["class"])
accruacy
# Out:
# 22255
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)
# 0.0624

# %%
text_classfication_true = pd.read_csv("NLP_dataset/MNLI_formatted/Shared_BaseTrain_MNLI.tsv",sep="\t")
MNLI_Basecase =  pd.read_csv("train_preds(train_only)/train_base_preds/train1_predictions.tsv",sep="\t")



Max_entailment = utils.top_entailment_per_target(MNLI_Basecase,"ENTAILMENT")

mapping_mask =  {0:"World" ,1:"Sports",2:"Business",3:"Sci/Tech"}

text_classfication_true["predicted"] =  Max_entailment["textid"].map(mapping_mask)
print(sum(Max_entailment["predicted"]=="ENTAILMENT"))

accruacy = sum(text_classfication_true["class"]==text_classfication_true["predicted"])/len(text_classfication_true["class"])
accruacy
# Out:
# 3136
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)
# 0.0628625

# %%
Max_entailment
# Out:
#         textid  target                        model  \
# 0            2       0  microsoft/deberta-base-mnli
# 1            3       1  microsoft/deberta-base-mnli
# 2            2       2  microsoft/deberta-base-mnli
# 3            1       3  microsoft/deberta-base-mnli
# 4            0       4  microsoft/deberta-base-mnli
# ...        ...     ...                          ...
# 119995       2  119995  microsoft/deberta-base-mnli
# 119996       2  119996  microsoft/deberta-base-mnli
# 119997       1  119997  microsoft/deberta-base-mnli
# 119998       1  119998  microsoft/deberta-base-mnli
# 119999       2  119999  microsoft/deberta-base-mnli
#
#                           tokenizer      predicted      prob  CONTRADICTION  \
# 0       microsoft/deberta-base-mnli        NEUTRAL  0.733460       0.171711
# 1       microsoft/deberta-base-mnli        NEUTRAL  0.981615       0.016622
# 2       microsoft/deberta-base-mnli  CONTRADICTION  0.585761       0.585761
# ...

# %%
text_classfication_true
# Out:
#         textid     class                                               text  \
# 0            0     World  Reuters - Short-sellers, Wall Street's dwindli...
# 1            1    Sports  Reuters - Short-sellers, Wall Street's dwindli...
# 2            2  Business  Reuters - Short-sellers, Wall Street's dwindli...
# 3            3  Sci/Tech  Reuters - Short-sellers, Wall Street's dwindli...
# 4            0     World  Reuters - Private investment firm Carlyle Grou...
# ...        ...       ...                                                ...
# 479995       3  Sci/Tech  PITTSBURGH at NY GIANTS Time: 1:30 p.m. Line: ...
# 479996       0     World  INDIANAPOLIS -- All-Star Vince Carter was trad...
# 479997       1    Sports  INDIANAPOLIS -- All-Star Vince Carter was trad...
# 479998       2  Business  INDIANAPOLIS -- All-Star Vince Carter was trad...
# 479999       3  Sci/Tech  INDIANAPOLIS -- All-Star Vince Carter was trad...
#
#                              pair  target predicted
# ...

# %% [markdown]
# # Evlauatioon on model 3

# %%
text_classfication_true = pd.read_csv("NLP_dataset/Base_test_textClassification_AgNews.tsv",sep="\t")
MNLI_Basecase =  pd.read_csv("Model_Outputs/Model_seed_3_Osvaldo/eval3_predictions.tsv",sep="\t")
Max_entailment = utils.top_entailment_per_target(MNLI_Basecase,"ENTAILMENT")

mapping_mask =  {0:"World" ,1:"Sports",2:"Business",3:"Sci/Tech"}

text_classfication_true["predicted"] =  Max_entailment["textid"].map(mapping_mask)
print(sum(Max_entailment["predicted"]=="ENTAILMENT"))

accruacy = sum(text_classfication_true["class"]==text_classfication_true["predicted"])/len(text_classfication_true["class"])
accruacy
# Out:
# 6674
# /Users/apple/Documents/GitHub/NLP_Midterm_Osvaldo_Yizhou_David/utils.py:16: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   idx = df.groupby('target')[entail].idxmax(axis=0)
# 0.2513157894736842

# %%
Max_entailment["textid"].map(mapping_mask).value_counts()
# Out:
# textid
# Sports      7502
# Business      61
# World         37
# Name: count, dtype: int64
