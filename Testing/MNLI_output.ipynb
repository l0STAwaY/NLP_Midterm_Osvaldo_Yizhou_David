# %%
import pandas as pd

data = { "textid" : [0,1,0,1] ,
        "class" : ["greeting","question", "greeting", "question"],
        "text": ["hello","hello","why","why"],
        "hypothesis" :["this is a greeting", "this is a question","this is a greeting", "this is a question"],
        "target" : [0,0,1,1]
}


output = pd.DataFrame(data)

# https://huggingface.co/docs/transformers/model_doc/roberta

output.to_csv("../Testing/example_data.tsv",sep="\t",index=False)
